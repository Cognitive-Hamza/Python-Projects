# %% [markdown]
# <a href="https://colab.research.google.com/github/Cognitive-Hamza/Python-Projects/blob/main/Random_Number_Guesser.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

print("Welcome to the Number Guessing Game!")
secret_number = random.randint(1, 100)
attempts = 0
guess = 0

while guess != secret_number:
    try:
        guess_str = input("Guess the number (1-100): ")
        guess = int(guess_str)
        attempts += 1

        if guess > secret_number:
            print("Too High")
        elif guess < secret_number:
            print("Too Low")
        else:
            print(f"Correct! You guessed it in {attempts} attempts 🎯")
    except ValueError:
        print("Invalid input. Please enter a valid number.")
# Out:
# Welcome to the Number Guessing Game!
# Guess the number (1-100): 10
# Too High
# Guess the number (1-100): 2
# Too Low
# Guess the number (1-100): 5
# Too High
# Guess the number (1-100): 4
# Too High
# Guess the number (1-100): 3
# Correct! You guessed it in 5 attempts 🎯
