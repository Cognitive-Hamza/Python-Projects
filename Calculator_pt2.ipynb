# %% [markdown]
# <a href="https://colab.research.google.com/github/Cognitive-Hamza/Python-Projects/blob/main/Calculator_pt2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Welcome the user
print("Simple Calculator")

welcome = "Welcome to the Caluculator!"
print(welcome)

# Ask user for numbers
num1_str = input("Enter the first number: ")
num2_str = input("Enter the second number: ")
num3_str = input("Enter the third number: ")

'''Convert first two inputs to integers,
we will convert the third one later because there might be case where the user only wants to operate two numbers not three.'''
num1 = int(num1_str)
num2 = int(num2_str)

# Give the user operations' options
print("Press 1 for addition '+'")
print("Press 2 for subtraction '-'")
print("Press 3 for multiplication '*'")
print("Press 4 for division '/'")

# Ask for the function
operator = input("Enter the first required operation: ")

# If for calculation
if operator == "1":
    result = (num1 + num2)
    print(result)

elif operator == "2":
    result = (num1 - num2)
    print(result)

elif operator == "3":
    result = (num1 * num2)
    print(result)

elif operator == "4":
    if num2 == 0:
        print("Error: Cannot divide by zero!")
        result = (0)
        print(result)
    else:
        result = (num1 / num2)
        print(result)

else:
    print("Invalid operator selected.")

'''Second operation,
This block will only execute if num3 was successfully converted to an integer'''

if num3_str != "":
    # Conversion will happen to int only if not empty
    num3 = int(num3_str)
    operator1 = input("Enter the second required operation: ")

    if operator1 == "1":
        result1 = (result + num3)
        print(result1)

    elif operator1 == "2":
        result1 = (result - num3)
        print(result1)

    elif operator1 == "3":
        result1 = (result * num3)
        print(result1)

    elif operator1 == "4":
        if num3 == 0:
            print("Error: Cannot divide by zero!")
        else:
            result1 = (result / num3)
            print(result1)

    else:
        print("Invalid operator selected.")
else:
  exit()
# Out:
# Simple Calculator
# Welcome to the Caluculator!
# Enter the first number: 2
# Enter the second number: 2
# Enter the third number: 0
# Press 1 for addition '+'
# Press 2 for subtraction '-'
# Press 3 for multiplication '*'
# Press 4 for division '/'
# Enter the first required operation: 2
# 0
# Enter the second required operation: 4
# Error: Cannot divide by zero!
