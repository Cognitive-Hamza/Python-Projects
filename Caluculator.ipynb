# %% [markdown]
# <a href="https://colab.research.google.com/github/Cognitive-Hamza/Python-Projects/blob/main/Caluculator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Skeleton of code:

# %%
# Welcome the user
print("Simple Calculator")

welcome = "Welcome to the Caluculator!"
print(welcome)

# Ask user for numbers

num1 = int(input("Enter the first number: "))
num2 = int(input("Enter the second number: "))

# Give the user operations' options

print("Press 1 for addition '+'")
print("Press 2 for subtraction '-'")
print("Press 3 for multiplication '*'")
print("Press 4 for division '/'")

# Ask for the function

operator = input("Enter the required operation: ")

# If for calculation

if operator == "1":
   print(num1 + num2)
elif operator == "2":
   print(num1 - num2)
elif operator == "3":
   print(num1 * num2)
elif operator == "4":
  if num2 == 0:
    print("Error: Cannot divide by zero!")
  else:
    print(num1 / num2)
else:
   print("Invalid operator selected.")
# Out:
# Simple Calculator
# Welcome to the Caluculator!
# Enter the first number: 5
# Enter the second number: 9
# Press 1 for addition '+'
# Press 2 for subtraction '-'
# Press 3 for multiplication '*'
# Press 4 for division '/'
# Enter the required operation: 8
# Invalid operator selected.

# %% [markdown]
# Code above is without any check and validation/verification checks.

# %% [markdown]
# #**Final Code:**

# %%
# Welcome the user
print("Simple Calculator")

welcome = "Welcome to the Calculator!"
print(welcome)

# Ask user for numbers
num1 = input("Enter the first number: ")

if num1.isdigit():
    num2 = input("Enter the second number: ")

    if num2.isdigit():
        num1 = int(num1)
        num2 = int(num2)

        # Give the user operations' options
        print("Press 1 for addition '+'")
        print("Press 2 for subtraction '-'")
        print("Press 3 for multiplication '*'")
        print("Press 4 for division '/'")

        # Ask for the function
        operator = input("Enter the required operation: ")

        # Perform calculation
        if operator == "1":
            print(num1 + num2)
        elif operator == "2":
            print(num1 - num2)
        elif operator == "3":
            print(num1 * num2)
        elif operator == "4":
            if num2 == 0:
                print("Error: Cannot divide by zero!")
            else:
                print(num1 / num2)
        else:
            print("Invalid operator selected.")
    else:
        print("Numbers only!!")
else:
    print("Numbers only!!")
# Out:
# Simple Calculator
# Welcome to the Calculator!
# Enter the first number: 0
# Enter the second number: 9
# Press 1 for addition '+'
# Press 2 for subtraction '-'
# Press 3 for multiplication '*'
# Press 4 for division '/'
# Enter the required operation: 2
# -9

# %% [markdown]
# ### Testing and adding checks through trial and error

# %%
# BASE CODE
#___________


# Welcome the user
print("Simple Calculator")

welcome = "Welcome to the Caluculator!"
print(welcome)

# Ask user for numbers

num1_text = input("Enter the first number: ")
num2_text = input("Enter the second number: ")



# Give the user operations' options

print("Press 1 for addition '+'")
print("Press 2 for subtraction '-'")
print("Press 3 for multiplication '*'")
print("Press 4 for division '/'")

# Ask for the function

operator = input("Enter the required operation: ")

# If for calculation

if operator == "1":
   print(num1 + num2)
elif operator == "2":
   print(num1 - num2)
elif operator == "3":
   print(num1 * num2)
elif operator == "4":
  if num2 == 0:
    print("Error: Cannot divide by zero!")
  else:
    print(num1 / num2)
else:
   print("Invalid operator selected.")
# Out:
# Simple Calculator
# Welcome to the Caluculator!
# Enter the first number: 0
# Enter the second number: 0
# Press 1 for addition '+'
# Press 2 for subtraction '-'
# Press 3 for multiplication '*'
# Press 4 for division '/'
# Enter the required operation: 0
# Invalid operator selected.

# %%
# Welcome the user
print("Simple Calculator")

welcome = "Welcome to the Calculator!"
print(welcome)

# Ask user for numbers (with validation)

num1_text = input("Enter the first number: ")
num2_text = input("Enter the second number: ")

# Check for empty input
if num1_text == "" or num2_text == "":
    print("Error: Empty input is not allowed.")
    exit()

# Check for non-numeric input
if num1_text.isdigit() or num2_text.isdigit():
    print("Error: Please enter numbers only.")
    exit()

# Convert to numbers
num1 = float(num1_text)
num2 = float(num2_text)

# Give the user operations' options
print("Press 1 for addition '+'")
print("Press 2 for subtraction '-'")
print("Press 3 for multiplication '*'")
print("Press 4 for division '/'")

# Ask for the function
operator = input("Enter the required operation: ").

# Perform calculation
if operator == "1":
    print(num1 + num2)

elif operator == "2":
    print(num1 - num2)

elif operator == "3":
    print(num1 * num2)

elif operator == "4":
    if num2 == 0:
        print("Error: Cannot divide by zero!")
    else:
        print(num1 / num2)

else:
    print("Invalid operator selected.")

else:
print("Error: Please enter numbers only.")
    exit()
# Out:
#   File "/tmp/ipython-input-283876830.py", line 33
#     operator = input("Enter the required operation: ").
#                                                        ^
# SyntaxError: invalid syntax

# %%
# Welcome the user
print("Simple Calculator")

welcome = "Welcome to the Calculator!"
print(welcome)

# Ask user for numbers (with validation)

num1_text = input("Enter the first number: ")
if num1_text == "":
  print("Error: Empty input is not allowed.")
  exit()
else:
  num2_text = input("Enter the second number: ")
  if num2_text == "":
    print("Error: Empty input is not allowed.")
    exit()
  else:

# Check for non-numeric input
if num1_text.isdigit():
 if num2_text.isdigit():


# Convert to numbers
num1 = float(num1_text)
num2 = float(num2_text)

# Give the user operations' options
print("Press 1 for addition '+'")
print("Press 2 for subtraction '-'")
print("Press 3 for multiplication '*'")
print("Press 4 for division '/'")

# Ask for the function
operator = input("Enter the required operation: ")

# Perform calculation
if operator == "1":
    print(num1 + num2)

elif operator == "2":
    print(num1 - num2)

elif operator == "3":
    print(num1 * num2)

elif operator == "4":
    if num2 == 0:
        print("Error: Cannot divide by zero!")
    else:
        print(num1 / num2)
else:
  print("Error: Please enter numbers only.")
    exit()
else:
  print("Error: Please enter numbers only.")
    exit()
else:
    print("Invalid operator selected.")
# Out:
# Simple Calculator
# Welcome to the Calculator!
# Enter the first number: kk
# Enter the second number: kk
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-4009529937.py in <cell line: 0>()
#      21
#      22 # Convert to numbers
# ---> 23 num1 = float(num1_text)
#      24 num2 = float(num2_text)
#      25
#
# ValueError: could not convert string to float: 'kk'

# %%
# Welcome the user
print("Simple Calculator")
print("=-=-=-=-=-=-=-=-=-=")

welcome = "Welcome to the Calculator!"
print(welcome)

# Ask user for numbers (with validation)

num1_text = input("Enter the first number: ")
if num1_text == "":
    print("Error: Empty input is not allowed.")
    exit()
else:
    num2_text = input("Enter the second number: ")
    if num2_text == "":
        print("Error: Empty input is not allowed.")
        exit()
    else:

        # Check for non-numeric input
        if num1_text.isdigit():
        else:
          print("Error: Please enter numbers only.")
          exit()
          if num2_text.isdigit():

                # Convert to numbers
                num1 = float(num1_text)
                num2 = float(num2_text)

                # Give the user operations' options
                print("Press 1 for addition '+'")
                print("Press 2 for subtraction '-'")
                print("Press 3 for multiplication '*'")
                print("Press 4 for division '/'")

                # Ask for the function
                operator = input("Enter the required operation: ")

                # Perform calculation
                if operator == "1":
                    print(num1 + num2)

                elif operator == "2":
                    print(num1 - num2)

                elif operator == "3":
                    print(num1 * num2)

                elif operator == "4":
                    if num2 == 0:
                        print("Error: Cannot divide by zero!")
                    else:
                        print(num1 / num2)

                else:
                    print("Invalid operator selected.")

            else:
                print("Error: Please enter numbers only.")
                exit()
# Out:
#   File "<tokenize>", line 60
#     else:
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
# Welcome the user
print("Simple Calculator")
print("=-=-=-=-=-=-=-=-=-=")

welcome = "Welcome to the Calculator!"
print(welcome)

# Ask user for numbers (with validation)

num1_text = input("Enter the first number: ")
if num1_text == "":
    print("Error: Empty input is not allowed.")
    exit()
else:
    num2_text = input("Enter the second number: ")
    if num2_text == "":
        print("Error: Empty input is not allowed.")
        exit()
    else:

        # Check for non-numeric input
        if not num1_text.isdigit():
          print("Error: Please enter numbers only.")
          exit()
        else:
          if num2_text.isdigit():

                # Convert to numbers
                num1 = float(num1_text)
                num2 = float(num2_text)

                # Give the user operations' options
                print("Press 1 for addition '+'")
                print("Press 2 for subtraction '-'")
                print("Press 3 for multiplication '*'")
                print("Press 4 for division '/'")

                # Ask for the function
                operator = input("Enter the required operation: ")

                # Perform calculation
                if operator == "1":
                    print(num1 + num2)

                elif operator == "2":
                    print(num1 - num2)

                elif operator == "3":
                    print(num1 * num2)

                elif operator == "4":
                    if num2 == 0:
                        print("Error: Cannot divide by zero!")
                    else:
                        print(num1 / num2)

                else:
                    print("Invalid operator selected.")

          else:
            print("Error: Please enter numbers only.")
            exit()
# Out:
# Simple Calculator
# =-=-=-=-=-=-=-=-=-=
# Welcome to the Calculator!
# Enter the first number: kkk
# Enter the second number: lll
# Error: Please enter numbers only.

# %%
# Welcome the user
print("Simple Calculator")
print("=-=-=-=-=-=-=-=-=-=")

welcome = "Welcome to the Calculator!"
print(welcome)

# Ask user for numbers (with validation)

num1_text = input("Enter the first number: ")
if num1_text == "":
    print("Error: Empty input is not allowed.")
    exit()
else:
    num2_text = input("Enter the second number: ")
    if num2_text == "":
        print("Error: Empty input is not allowed.")
        exit()
    else:

        # Check for non-numeric input
        if not num1_text.isdigit():
          print("Error: Please enter numbers only.")
          exit()
        else:
          if num2_text.isdigit():

                # Convert to numbers
                num1 = float(num1_text)
                num2 = float(num2_text)

                # Give the user operations' options
                print("Press 1 for addition '+'")
                print("Press 2 for subtraction '-'")
                print("Press 3 for multiplication '*'")
                print("Press 4 for division '/'")

                # Ask for the function
                operator = input("Enter the required operation: ")

                # Perform calculation
                if operator == "1":
                    print(num1 + num2)

                elif operator == "2":
                    print(num1 - num2)

                elif operator == "3":
                    print(num1 * num2)

                elif operator == "4":
                    if num2 == 0:
                        print("Error: Cannot divide by zero!")
                    else:
                        print(num1 / num2)

                else:
                    print("Invalid operator selected.")

          else:
            print("Error: Please enter numbers only.")
            exit()
# Out:
# Simple Calculator
# =-=-=-=-=-=-=-=-=-=
# Welcome to the Calculator!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-1265756079.py in <cell line: 0>()
#       8 # Ask user for numbers (with validation)
#       9
# ---> 10 num1_text = input("Enter the first number: ")
#      11 if num1_text == "":
#      12     print("Error: Empty input is not allowed.")
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
# ...

# %%
# Welcome the user
print("Simple Calculator")
print("=-=-=-=-=-=-=-=-=-=")

welcome = "Welcome to the Calculator!"
print(welcome)

# Ask user for numbers (with validation)

num1_text = float(input("Enter the first number: "))
if num1_text == "":
    print("Error: Empty input is not allowed.")
    exit()
elif type(num1_text) == type("g"):
  print("Error: String input is not allowed.")
  exit()
  num2_text = input("Enter the second number: ")
  if num2_text == "":
    print("Error: Empty input is not allowed.")
    exit()
  else:

  # Give the user operations' options
  print("Press 1 for addition '+'")
  print("Press 2 for subtraction '-'")
  print("Press 3 for multiplication '*'")
  print("Press 4 for division '/'")

  # Ask for the function
  operator = input("Enter the required operation: ")

  # Perform calculation
    if operator == "1":
      print(num1 + num2)

    elif operator == "2":
      print(num1 - num2)

    elif operator == "3":
      print(num1 * num2)

    elif operator == "4":
      if num2 == 0:
        print("Error: Cannot divide by zero!")
      else:
        print(num1 / num2)
    else:
      print("Invalid operator selected.")
elif print("Error: Please enter numbers only.")
     exit()
else:
  print("Error: Please enter numbers only.")
  exit()
# Out:
#   File "/tmp/ipython-input-2388346088.py", line 24
#     print("Press 1 for addition '+'")
#     ^
# IndentationError: expected an indented block after 'else' statement on line 21

# %%
# Welcome the user
print("Simple Calculator")
print("=-=-=-=-=-=-=-=-=-=")

welcome = "Welcome to the Calculator!"
print(welcome)

# Ask user for numbers (with validation)

num1_text = float(input("Enter the first number: "))
if num1_text == "":
    print("Error: Empty input is not allowed.")
    exit()

elif type(num1_text) == type("g"):
    print("Error: String input is not allowed.")
    exit()

    num2_text = input("Enter the second number: ")
    if num2_text == "":
        print("Error: Empty input is not allowed.")
        exit()
    else:

        # Give the user operations' options
        print("Press 1 for addition '+'")
        print("Press 2 for subtraction '-'")
        print("Press 3 for multiplication '*'")
        print("Press 4 for division '/'")

        # Ask for the function
        operator = input("Enter the required operation: ")

        # Perform calculation
        if operator == "1":
            print(num1 + num2)

        elif operator == "2":
            print(num1 - num2)

        elif operator == "3":
            print(num1 * num2)

        elif operator == "4":
            if num2 == 0:
                print("Error: Cannot divide by zero!")
            else:
                print(num1 / num2)
        else:
            print("Invalid operator selected.")

elif print("Error: Please enter numbers only."):
    exit()


else:
    print("Error: Please enter numbers only.")
    exit()
# Out:
# Simple Calculator
# =-=-=-=-=-=-=-=-=-=
# Welcome to the Calculator!
# Enter the first number: 5.1
# Error: Please enter numbers only.
# Error: Please enter numbers only.

# %%
# Welcome the user
print("Simple Calculator")

welcome = "Welcome to the Caluculator!"
print(welcome)

# Ask user for numbers

num1 = input("Enter the first number: ")

if num1.isdigit():
  num2 = input("Enter the second number: ")
  if num2.isidgit():

# Give the user operations' options

print("Press 1 for addition '+'")
print("Press 2 for subtraction '-'")
print("Press 3 for multiplication '*'")
print("Press 4 for division '/'")

# Ask for the function

operator = input("Enter the required operation: ")

# If for calculation

if operator == "1":
   print(num1 + num2)
elif operator == "2":
   print(num1 - num2)
elif operator == "3":
   print(num1 * num2)
elif operator == "4":
  if num2 == 0:
    print("Error: Cannot divide by zero!")
  else:
    print(num1 / num2)
else:
   print("Invalid operator selected.")
else:
  print("Numbers only!!")
else:
  print("Numbers only!!")
# Out:
# Simple Calculator
# Welcome to the Caluculator!
# Enter the first number: 5
# Enter the second number: 9
# Press 1 for addition '+'
# Press 2 for subtraction '-'
# Press 3 for multiplication '*'
# Press 4 for division '/'
# Enter the required operation: 8
# Invalid operator selected.

# %%
# Welcome the user
print("Simple Calculator")

welcome = "Welcome to the Caluculator!"
print(welcome)

# Ask user for numbers
num1 = int(input("Enter the first number: "))
if type(num1) == type(1):
    num2 = int(input("Enter the second number: "))
    if type(num2) == type(1):

        # Give the user operations' options
        print("Press 1 for addition '+'")
        print("Press 2 for subtraction '-'")
        print("Press 3 for multiplication '*'")
        print("Press 4 for division '/'")

        # Ask for the function
        operator = input("Enter the required operation: ")

        # If for calculation
        if operator == "1":
            print(num1 + num2)
        elif operator == "2":
            print(num1 - num2)
        elif operator == "3":
            print(num1 * num2)
        elif operator == "4":
            if num2 == 0:
                print("Error: Cannot divide by zero!")
            else:
                print(num1 / num2)
        else:
            print("Invalid operator selected.")
    else:
        print("Numbers only!!")
else:
    print("Numbers only!!")
# Out:
# Simple Calculator
# Welcome to the Caluculator!
# Enter the first number: l
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-1368982468.py in <cell line: 0>()
#       6
#       7 # Ask user for numbers
# ----> 8 num1 = int(input("Enter the first number: "))
#       9 if type(num1) == type(1):
#      10     num2 = int(input("Enter the second number: "))
#
# ValueError: invalid literal for int() with base 10: 'l'

# %%
num1=1

# %%
if type(num1)==type(1.5):
  print("fubuiuibviu")

# %%
type(num1)
# Out:
# float

# %%
type(float)
# Out:
# type

# %%
num1_text="1.5"

# %%
num1_text.isdecimal()
# Out:
# False

# %%
num1 = 1
type(num1)
# Out:
# int
