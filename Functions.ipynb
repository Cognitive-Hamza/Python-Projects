# %% [markdown]
# <a href="https://colab.research.google.com/github/Cognitive-Hamza/Python-Projects/blob/main/Functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#A. Function that takes 2 no. and returns sum.
def add(a, b):
	return a + b

#Test your function
result = add(5, 7)
print ("Sum is:", result)

#B. Procedure(func with no return) that print welcome msg with name.
def greet(name):
	print("Hello", name, "welcome to the lab!")

greet("Sara")
greet("Bilal")
# Out:
# Sum is: 12
# Hello Sara welcome to the lab!
# Hello Bilal welcome to the lab!
